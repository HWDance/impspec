# %%
os.chdir("./causalklgp")

# %%
# Imports
import torch
import os 
import sys
from dask_jobqueue import SLURMCluster
from distributed import Client
from pathlib import Path


import do_abelation_causalklgp

# %%
# Args setup
ntrial = 50
n = 100
ntest = 1000
d = 5
noise = 1.0
calibrate = [False,True, True, True]
calibrate_latent = [False, False, True, True]
train_calibration_model = [False, False, False, True]

# %%
# Cluster creation
cluster = SLURMCluster(
    n_workers=0,
    memory="32GB",
    processes=1,
    cores=1,
    scheduler_options={
        "dashboard_address": ":11111",
        "allowed_failures": 10
    },
    job_cpu=1,
    walltime="6:0:0",
    
    #job_extra_directives = ["-p medium,cpu"],
)
cluster.adapt(minimum=0, maximum=200)
client = Client(cluster)

# %%
# Submitting jobs
futures = []
for i in range(len(calibrate)):           
    for seed in range(ntrial):
            f = client.submit(do_abelation_causalklgp.main,seed,n,ntest,d,noise,
                             calibrate = calibrate[i], cal_latent = calibrate_latent[i],
                             traincalmodel = train_calibration_model[i])
            futures += [f]

# %%
# Check on futures
futures
# Out:
# [<Future: pending, key: main-a2c99c4fa00cf8243e785ef1cfd196d9>,
#  <Future: pending, key: main-5e77c1f1d5855b9acfd19bcaf411c43c>,
#  <Future: pending, key: main-3c61e972a259c11efe321226c11da2ac>,
#  <Future: pending, key: main-01ce7cb7e527d45fe905c9bf247d950a>,
#  <Future: pending, key: main-0475b27f05685befb86656e2d346c6ab>,
#  <Future: pending, key: main-869e3e9a17bf4525a4c9f708ebc1243b>,
#  <Future: pending, key: main-470ce3599001a21144863825144ce121>,
#  <Future: pending, key: main-63f1475225810ca4aaa2fa3a63d98298>,
#  <Future: pending, key: main-32e673f2d7dbf7d50e885a0c29ef8a09>,
#  <Future: pending, key: main-bb7ecec414d45b21f171dd8abc12c048>,
#  <Future: pending, key: main-24d1956603fe9dde1e40302f40d40347>,
#  <Future: pending, key: main-cbcfa7d09dc89ec8c9cf0759abce2195>,
#  <Future: pending, key: main-04d3e0de6203b40022d8c6f9f34c1540>,
#  <Future: pending, key: main-8b00c1c3df063750c2a000963f1962ee>,
#  <Future: pending, key: main-f6b542acc6ec874c7a2896f730139b11>,
#  <Future: pending, key: main-2ca8548ec39bf66ce1cbab9a3287c8df>,
#  <Future: pending, key: main-722b7799822b7dde206feaa5e8d6c8e4>,
#  <Future: pending, key: main-7962d0af17ee37040b0fb3a3e5e9400d>,
#  <Future: pending, key: main-3e9b16a1420c67c5d29d9cf13d82e17d>,
#  <Future: pending, key: main-501e86f71c7508abec773c2e044ea574>,
#  <Future: pending, key: main-763c1b41f31c27606ca472fcb0cd0fe5>,
#  <Future: pending, key: main-2591cd22cdce02d06df2b3a3138f7deb>,
#  <Future: pending, key: main-57e975dfbb25e3716634a301b6c1df06>,
#  <Future: pending, key: main-87984516d6e9b502612b67cff13c4f8b>,
#  <Future: pending, key: main-97cb27b7dd740be46a38ff1a3d871b81>,
#  <Future: pending, key: main-29f309508f4a55170afe924d2eab7536>,
#  <Future: pending, key: main-f133528ff659946313fe86411a69b8bf>,
#  <Future: pending, key: main-1ebb6d5c58036d6f68dabf0bbafa8c60>,
#  <Future: pending, key: main-750d4bf1d374f7021b0ff9654b9b0a62>,
#  <Future: pending, key: main-f21b9e8ab35f75e619a1a81fdfc15adb>,
#  <Future: pending, key: main-a7c18d53263cebabcb068a18e15f2275>,
#  <Future: pending, key: main-9e18baf0c3be0ca4d85d2e60953dc228>,
#  <Future: pending, key: main-18ed67ded43976683aeca6fdac97a9db>,
#  <Future: pending, key: main-6ce08e187c17a8abab7035645fcde33b>,
#  <Future: pending, key: main-845e8ef2dfd68529c4c1c7332599ce3b>,
#  <Future: pending, key: main-c7ccc254fa402f58004e55e1a97cc464>,
#  <Future: pending, key: main-e37fcf299954405ae37a63bf8ef7a491>,
#  <Future: pending, key: main-1b17d481fff73abe975302b1f431c156>,
#  <Future: pending, key: main-48602804dbbd1c499917fed9768f0bb9>,
#  <Future: pending, key: main-4b3157df862b16821da907923ccf6a29>,
#  <Future: pending, key: main-7bb2e1c0793159d5827eed1010019288>,
#  <Future: pending, key: main-7b53261f1a8c0e7f1f87fa6e3bb49a8d>,
#  <Future: pending, key: main-489b0ca52241e8d368e44b9b69a16205>,
#  <Future: pending, key: main-dfe4af900f16a84645a144dcfcdeaeda>,
#  <Future: pending, key: main-2a3e9091b42e6e8a2aecf924a2a41639>,
#  <Future: pending, key: main-bf6508e66682602a26286ae422909bf2>,
#  <Future: pending, key: main-d41e2184d096a3b933d3d5819d94def7>,
#  <Future: pending, key: main-2d49a1043804fb685113fcec70ae3096>,
#  <Future: pending, key: main-4388ca4eb7074e4231998eaabb8157f8>,
#  <Future: pending, key: main-a07a1ce0e3825b0cc08e5d58787d0639>,
#  <Future: pending, key: main-2b58de370d6f5e315157ab7a70278044>,
#  <Future: pending, key: main-a09190e957f0baf308ae2bee2f915f19>,
#  <Future: pending, key: main-4367b014495c9b09523754ea82830217>,
#  <Future: pending, key: main-522d451e46d76dd0c9cc2fe2da3fa95d>,
#  <Future: pending, key: main-fb73875d8e9db7bb007050c5fcc6796b>,
#  <Future: pending, key: main-9cfff5d47ae83a35e2dacd660a9bf763>,
#  <Future: pending, key: main-d9d10152a858c292900374bdfc0bdfa3>,
#  <Future: pending, key: main-380924405101dd9f7d1cffa7e2131cff>,
#  <Future: pending, key: main-4a3d8a2fa6a5cb574194eabc0dc02f50>,
#  <Future: pending, key: main-bdfac26dfe130c44a33e249589e4adb8>,
#  <Future: pending, key: main-33b35cc1c69c9ec88f08f7def5211387>,
#  <Future: pending, key: main-bfc88450d9b1694c0ffa8931ba47858f>,
#  <Future: pending, key: main-1ffa94a7f8307080c1daca796026a198>,
#  <Future: pending, key: main-923e0002c36d0192c2548e9cb72723f5>,
#  <Future: pending, key: main-25bc5ff26396715e018814ec777415eb>,
#  <Future: pending, key: main-b1783404d0380f2bc5082cfe047dfb58>,
#  <Future: pending, key: main-efd763f6db05d4ddfb9101d094497988>,
#  <Future: pending, key: main-7f23cc4d6d870ef070499531be8cc8a1>,
#  <Future: pending, key: main-0ef4d7a817dc2d6eada85246104bab0d>,
#  <Future: pending, key: main-08d2e25f66dcff025131f7e393fd5bd8>,
#  <Future: pending, key: main-d6dbf14bf8d3830a8e98b4bff8131cd6>,
#  <Future: pending, key: main-dc5529470ce512e89ef58f0789d1e94c>,
#  <Future: pending, key: main-47c1bd69b4b3f704f687820d93bcc894>,
#  <Future: pending, key: main-14233bfd9c74a2f8db312537fca60971>,
#  <Future: pending, key: main-39794a4eeea30d868b4e3fa747c499d7>,
#  <Future: pending, key: main-2e7937f853ca85336b4ba2e76d353720>,
#  <Future: pending, key: main-2eac86e7b3a718f5cb0a263ee437ef6c>,
#  <Future: pending, key: main-df5f21e717cbb65b5e33542f032aa3d6>,
#  <Future: pending, key: main-a7268f684059a290fb425cc5a5b7e06e>,
#  <Future: pending, key: main-e058f32b8c7b1c3d5a3840573da0d347>,
#  <Future: pending, key: main-237ea36bffd92d0d74168d786823454b>,
#  <Future: pending, key: main-966099c0bb026ce0d073d8cf1c122f9c>,
#  <Future: pending, key: main-029467852eb66cb7fed6dc466d20c392>,
#  <Future: pending, key: main-4e98b07f21384090d16a89a15ea51d48>,
#  <Future: pending, key: main-6d933dbc5ee00007566fb5a2e9e9caac>,
#  <Future: pending, key: main-7a3523cf1a92f8faa2f506ce45ca4c37>,
#  <Future: pending, key: main-a1b4ec7285a9e79ca4e5a5e1b1e89f05>,
#  <Future: pending, key: main-51b5f8613747a9428ebe86b2c8edcae1>,
#  <Future: pending, key: main-1eae4d9db7d7b2337cf73cb0eb55d27d>,
#  <Future: pending, key: main-a3d35e415af762ca8e632b97121e51c1>,
#  <Future: pending, key: main-5e95e4f98eaf5d6768ecdfc8a84f81c2>,
#  <Future: pending, key: main-5064c99d802ea633feb7bd3cf0b5972a>,
#  <Future: pending, key: main-b3f5a5f46d57ee372c7b7849aae2a2a0>,
#  <Future: pending, key: main-140ee28b888127cc3e1d46dc88303941>,
#  <Future: pending, key: main-7a21c8c81e4cbfb1775f1a0548c99917>,
#  <Future: pending, key: main-951f36aa9666c9fcce55f70adf5e8e85>,
#  <Future: pending, key: main-eeca815932315771d7f9868e9a99fea8>,
#  <Future: pending, key: main-6cd71f09ba3d0876ee0754803ad08f89>,
#  <Future: pending, key: main-1d3e250120e4e2bc4e3b202a1a066f06>,
#  <Future: pending, key: main-c79589c4ccc25dd49fd39ed4cf7c6c41>,
#  <Future: pending, key: main-2166396e5facb176d1bf19818d0c6837>,
#  <Future: pending, key: main-a0e1113d3436bba8fed2a5200a4eb286>,
#  <Future: pending, key: main-9e287861a3a045f75a72a72c37828fa0>,
#  <Future: pending, key: main-75651ed84320efe065bbf47ea49a4401>,
#  <Future: pending, key: main-07126127c34b4a8828780f8758d4b0e4>,
#  <Future: pending, key: main-ecec61d56db442c938a23b727946c7e2>,
#  <Future: pending, key: main-487c435bed58f9f8b6ffaf4a88b488ba>,
#  <Future: pending, key: main-d35d5ea8959fee755fb8fa9980414f70>,
#  <Future: pending, key: main-847ede05a537c8c8007c78b6513341e4>,
#  <Future: pending, key: main-4d3ce5a036abbcc188d4a7a123f82a6d>,
#  <Future: pending, key: main-aa207a8deff7de6c1217478afbc722b4>,
#  <Future: pending, key: main-0984ae48e95b9fe5da5a61a4a02c159a>,
#  <Future: pending, key: main-70897ac184a77fcce131490a38c94032>,
#  <Future: pending, key: main-6e3cd40e2ef55938c19c5bc80f99d63c>,
#  <Future: pending, key: main-4e7672ca198205bcacfabe3210b615af>,
#  <Future: pending, key: main-bfbc240273290b589be4b5d720a18825>,
#  <Future: pending, key: main-a72be70da5b2d311d870c860f7ccc5be>,
#  <Future: pending, key: main-5b0dd0d75dbee0f8c7b930dd4a5eb012>,
#  <Future: pending, key: main-6aa32d1f427b027f2eaab1c08490a85c>,
#  <Future: pending, key: main-52aa20b90bce54f96d656b7de76fa2f0>,
#  <Future: pending, key: main-14b42021f67c5610e8ae5948df04473d>,
#  <Future: pending, key: main-26a0ddb6d9c03d1eaf1fb74e15e5a812>,
#  <Future: pending, key: main-8b3c37efb679f295734b33e677ff8a09>,
#  <Future: pending, key: main-458b4840b9a82ea8972b8a91dab10721>,
#  <Future: pending, key: main-b41335fb8617bd93b19f826787cba418>,
#  <Future: pending, key: main-95c91335c92a75c7c279850511e41b65>,
#  <Future: pending, key: main-a25bba7c508e5ad225bf69ce1296a088>,
#  <Future: pending, key: main-eecd01c7b0b630187c643412d6b26fd2>,
#  <Future: pending, key: main-c2ed76e4324e5470ea6b79a50f9b8d78>,
#  <Future: pending, key: main-0b900ff37ba59337264ac90168b73996>,
#  <Future: pending, key: main-3763a27a5a75932cc779fabf86c8efeb>,
#  <Future: pending, key: main-a670890e3556bdbe44733359ce2e7453>,
#  <Future: pending, key: main-b10bed692f0656a20041770e15e05ae7>,
#  <Future: pending, key: main-1ea64e55346238a6fe7a232cf71bf472>,
#  <Future: pending, key: main-172538fb622678a3638bbf18a1a1c58e>,
#  <Future: pending, key: main-c642985f30cd896b8d794ae528717da4>,
#  <Future: pending, key: main-a3081966bcf3844c5d1a090082338747>,
#  <Future: pending, key: main-d2032f477621965d6db570fabd917790>,
#  <Future: pending, key: main-19cf10cca2a3aba87d308fab509f4b11>,
#  <Future: pending, key: main-58f3badaec61b308eb7d8a41744a635d>,
#  <Future: pending, key: main-2ace0e79c25ca406fd736097b2f8607a>,
#  <Future: pending, key: main-aef4e67751600e066024eddd6bfce7ce>,
#  <Future: pending, key: main-494798727909db40428b4ee37075cbeb>,
#  <Future: pending, key: main-afc3b5930248cb08afdd0e7faaf16141>,
#  <Future: pending, key: main-af6895677e7763a138febbb7c3065ac7>,
#  <Future: pending, key: main-cce05d23e9a1ada9145e6ccd9bb1a0de>,
#  <Future: pending, key: main-718fb7abc42a93b1614d06a9949497e3>,
#  <Future: pending, key: main-14c5f9dc46dd88375f550334c27ad5ad>,
#  <Future: pending, key: main-10825aff0f62b5db9442aeb960d7f482>,
#  <Future: pending, key: main-712bfd1efb29182f7ae5943f98aca59d>,
#  <Future: pending, key: main-6ca9e0ce13a861656596ab8896a44260>,
#  <Future: pending, key: main-439ade69cda1cefdb9407f920468cb62>,
#  <Future: pending, key: main-8abd7afd4ad7c80ca614254bad5c2532>,
#  <Future: pending, key: main-aeb54d33d0629f24f046ea044d3728f6>,
#  <Future: pending, key: main-ec635f56da2260213f7ba6ac99b37f49>,
#  <Future: pending, key: main-2998ab816119ac92548670dc561590c4>,
#  <Future: pending, key: main-a6c09e5e36c5be645934befae0f3b685>,
#  <Future: pending, key: main-8b9878f3a92fb6642f4fbd6c6b3ee3b4>,
#  <Future: pending, key: main-e88cfd60578a98853ff900333cfb3b88>,
#  <Future: pending, key: main-df6df66b24673e05809bbaa09475a667>,
#  <Future: pending, key: main-f151e88554ae99e60a5999a2d19c2a2c>,
#  <Future: pending, key: main-851eb2fe50147321dc32ab2bf5f8dd54>,
#  <Future: pending, key: main-c602eff9fc7aeb17dde3f66ad823d343>,
#  <Future: pending, key: main-19d213d14c35c4018b52bb0a16d95b41>,
#  <Future: pending, key: main-6f38d712a69805de7878d07a501b755a>,
#  <Future: pending, key: main-af77e48eb3fefc150a94a1a2c4caadf2>,
#  <Future: pending, key: main-2b313b62849dd3159543dd0088850921>,
#  <Future: pending, key: main-4d628cd7aea90edb09181323995f905b>,
#  <Future: pending, key: main-7f74c399bff30195f78afd705361ac91>,
#  <Future: pending, key: main-ffa01b1a490bdbf254c930fb3c9cd958>,
#  <Future: pending, key: main-f1435e9abb57e15c06f1be1868d2f46a>,
#  <Future: pending, key: main-e6e2fefedf2a1ae2cf136dd1aa0dcd83>,
#  <Future: pending, key: main-fa1d37aa9f649d7738d4956b778ecbbb>,
#  <Future: pending, key: main-43fa9ca8b62818e8e131ac4e01976eb9>,
#  <Future: pending, key: main-8c821d4c4d724fc054f867d4f5e48e0f>,
#  <Future: pending, key: main-30d0d2af1c510238beed972a200e0992>,
#  <Future: pending, key: main-00bd849df6eec0b7ef31c7875d944500>,
#  <Future: pending, key: main-270a4aabbe671b5a624ad1d2be271b33>,
#  <Future: pending, key: main-34b4b60e64dd5b43a11ec1bbe857561f>,
#  <Future: pending, key: main-7afa0d8ae1040f8632da4b9a83210b4f>,
#  <Future: pending, key: main-1ca7ba1f796ee5ea88d0f9426314b5cd>,
#  <Future: pending, key: main-c8d14d209e00227347e2a1498be6fa33>,
#  <Future: pending, key: main-ad7e87093a39d0e29b04cd77a7965f9f>,
#  <Future: pending, key: main-237b6b25bf8a051a935599188af50f36>,
#  <Future: pending, key: main-85c8262b095bd818a3f036cdf072ae2e>,
#  <Future: pending, key: main-f761ab4fb9977a2d551c89c779089c3e>,
#  <Future: pending, key: main-3bad2e8d8e8c80a2e748e04151a384ee>,
#  <Future: pending, key: main-1fdd70be032b2c9bce42dd4083aebaa3>,
#  <Future: pending, key: main-986502e3e6a6a5e68017ed6998cd8d02>,
#  <Future: pending, key: main-6fab137e0856e8e540d06d54ae808a67>,
#  <Future: pending, key: main-4b777ac659a8a72cc730e416c5deab32>,
#  <Future: pending, key: main-c872701a215eb8a5f2e85ad4627fa19b>,
#  <Future: pending, key: main-18986c657913f34cba1513f7dc1b2709>,
#  <Future: pending, key: main-5c1edb0307eb6c97b64c8f8381b18918>,
#  <Future: pending, key: main-064af3f7e5f3f6ae65a418d383f3c820>,
#  <Future: pending, key: main-4df95f77777532690599a0c3dcd98475>,
#  <Future: pending, key: main-a103a4de80f7261595a86abe97bf536a>,
#  <Future: pending, key: main-336f3a4adedf4b9d184078df3169cf55>,
#  <Future: pending, key: main-ef62ccf61832bd2a41d8b2dbec461138>,
#  <Future: pending, key: main-ecc5d1d4a39232ddfd039e190a59d267>]

# %%
# Getting results
results = client.gather(futures)

# %%
# Closing client
client.close()
cluster.close()

# %%
# Saving results
torch.save(obj = results,
           f = "abelation_causalklgp_ntrial={0}_n={1}_d={2}_noise={3}.pt".format(ntrial,n,d,noise))
